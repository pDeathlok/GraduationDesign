#  [10, 0.07, 0.3, 792, 1.0],
#  [10, 0.07, 0.5, 768, 1.0],
#  [10, 0.07, 0.6, 747, 1.0],
#  [10, 0.1, 0, 783, 1.0],
#  [10, 0.1, 0.05, 782, 1.0],
#  [10, 0.1, 0.1, 782, 1.0],
#  [10, 0.1, 0.2, 768, 1.0],
#  [10, 0.1, 0.3, 747, 1.0],
#  [10, 0.1, 0.5, 710, 1.0],
#  [10, 0.1, 0.6, 709, 1.0],
#  [10, 0.15, 0, 731, 1.0],
#  [10, 0.15, 0.05, 730, 1.0],
#  [10, 0.15, 0.1, 730, 1.0],
#  [10, 0.15, 0.2, 709, 1.0],
#  [10, 0.15, 0.3, 686, 1.0],
#  [10, 0.15, 0.5, 644, 0.989247311827957],
#  [10, 0.15, 0.6, 642, 0.989247311827957],
#  [10, 0.2, 0, 686, 1.0],
#  [10, 0.2, 0.05, 686, 1.0],
#  [10, 0.2, 0.1, 686, 1.0],
#  [10, 0.2, 0.2, 684, 1.0],
#  [10, 0.2, 0.3, 644, 0.989247311827957],
#  [10, 0.2, 0.5, 568, 0.967741935483871],
#  [10, 0.2, 0.6, 568, 0.967741935483871],
#  [30, 0.07, 0, 789, 1.0],
#  [30, 0.07, 0.05, 784, 1.0],
#  [30, 0.07, 0.1, 779, 1.0],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create Map
cm = plt.get_cmap("RdYlGn")

x = np.random.rand(30)
y = np.random.rand(30)
z = np.random.rand(30)

col = np.arange(30)

fig = plt.figure()
ax3D = fig.add_subplot(111, projection='3d')
ax3D.scatter(x, y, z, s=30, c=col, marker='o', cmap=cm)

plt.savefig('image1.png')
plt.savefig('image2.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


xs10 = [i[1] for i in ori if i[0] == 10]
ys10 = [i[2] for i in ori if i[0] == 10]
zs10 = [i[4] for i in ori if i[0] == 10]

xs30 = [i[1] for i in ori if i[0] == 30]
ys30 = [i[2] for i in ori if i[0] == 30]
zs30 = [i[4] for i in ori if i[0] == 30]

xs60 = [i[1] for i in ori if i[0] == 60]
ys60 = [i[2] for i in ori if i[0] == 60]
zs60 = [i[4] for i in ori if i[0] == 60]

xs120 = [i[1] for i in ori if i[0] == 120]
ys120 = [i[2] for i in ori if i[0] == 120]
zs120 = [i[4] for i in ori if i[0] == 120]

ax.scatter(xs10, ys10, zs10, c='r', marker='o')
ax.scatter(xs30, ys30, zs30, c='b', marker='o')
ax.scatter(xs60, ys60, zs60, c='y', marker='o')
ax.scatter(xs120, ys120, zs120, c='g', marker='o')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


xs10 = [i[1] for i in ori if i[0] == 10]
ys10 = [i[2] for i in ori if i[0] == 10]
zs10 = [i[3] for i in ori if i[0] == 10]

xs30 = [i[1] for i in ori if i[0] == 30]
ys30 = [i[2] for i in ori if i[0] == 30]
zs30 = [i[3] for i in ori if i[0] == 30]

xs60 = [i[1] for i in ori if i[0] == 60]
ys60 = [i[2] for i in ori if i[0] == 60]
zs60 = [i[3] for i in ori if i[0] == 60]

xs120 = [i[1] for i in ori if i[0] == 120]
ys120 = [i[2] for i in ori if i[0] == 120]
zs120 = [i[3] for i in ori if i[0] == 120]

ax.scatter(xs10, ys10, zs10, c='r', marker='o')
ax.scatter(xs30, ys30, zs30, c='b', marker='o')
ax.scatter(xs60, ys60, zs60, c='y', marker='o')
ax.scatter(xs120, ys120, zs120, c='g', marker='o')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)

xs10 = [i[1] for i in ori if i[0] == 10]
ys10 = [i[2] for i in ori if i[0] == 10]
zs10 = [i[3] for i in ori if i[0] == 10]
# Plot a basic wireframe.
ax.plot_wireframe(xs10, ys10, zs10, rstride=10, cstride=10)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

xs10_0 = [0.07 for i in xrange(7)]
ys10_0 = [i[2] for i in ori if i[0] == 10 and i[1] == 0.07]
zs10_0 = [i[3] for i in ori if i[0] == 10 and i[1] == 0.07]
xs10_1 = [0.1 for i in xrange(7)]
ys10_1 = [i[2] for i in ori if i[0] == 10 and i[1] == 0.1]
zs10_1 = [i[3] for i in ori if i[0] == 10 and i[1] == 0.1]
xs10_2 = [0.15 for i in xrange(7)]
ys10_2 = [i[2] for i in ori if i[0] == 10 and i[1] == 0.15]
zs10_2 = [i[3] for i in ori if i[0] == 10 and i[1] == 0.15]
xs10_3 = [0.2 for i in xrange(7)]
ys10_3 = [i[2] for i in ori if i[0] == 10 and i[1] == 0.2]
zs10_3 = [i[3] for i in ori if i[0] == 10 and i[1] == 0.2]

xs30_0 = [0.07 for i in xrange(7)]
ys30_0 = [i[2] for i in ori if i[0] == 30 and i[1] == 0.07]
zs30_0 = [i[3] for i in ori if i[0] == 30 and i[1] == 0.07]
xs30_1 = [0.1 for i in xrange(7)]
ys30_1 = [i[2] for i in ori if i[0] == 30 and i[1] == 0.1]
zs30_1 = [i[3] for i in ori if i[0] == 30 and i[1] == 0.1]
xs30_2 = [0.15 for i in xrange(7)]
ys30_2 = [i[2] for i in ori if i[0] == 30 and i[1] == 0.15]
zs30_2 = [i[3] for i in ori if i[0] == 30 and i[1] == 0.15]
xs30_3 = [0.2 for i in xrange(7)]
ys30_3 = [i[2] for i in ori if i[0] == 30 and i[1] == 0.2]
zs30_3 = [i[3] for i in ori if i[0] == 30 and i[1] == 0.2]

ax.plot_wireframe(xs10_0, ys10_0, zs10_0, rstride=10, cstride=10, color = 'b')
ax.plot_wireframe(xs10_1, ys10_1, zs10_1, rstride=10, cstride=10, color = 'b')
ax.plot_wireframe(xs10_2, ys10_2, zs10_2, rstride=10, cstride=10, color = 'b')
ax.plot_wireframe(xs10_3, ys10_3, zs10_3, rstride=10, cstride=10, color = 'b')

ax.plot_wireframe(xs30_0, ys30_0, zs30_0, rstride=10, cstride=10, color = 'r')
ax.plot_wireframe(xs30_1, ys30_1, zs30_1, rstride=10, cstride=10, color = 'r')
ax.plot_wireframe(xs30_2, ys30_2, zs30_2, rstride=10, cstride=10, color = 'r')
ax.plot_wireframe(xs30_3, ys30_3, zs30_3, rstride=10, cstride=10, color = 'r')

plt.show()
